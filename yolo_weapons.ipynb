# %%
import torch
print("GPU Available:", torch.cuda.is_available())
print("GPU Name:", torch.cuda.get_device_name(0))
# Out:
# GPU Available: True
# GPU Name: NVIDIA GeForce RTX 3050 Laptop GPU

# %%
import os
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"  # Forces CUDA to report errors immediately

from ultralytics import YOLO

# Use 'yolo11s.pt' (small) instead of medium to stay within 4GB VRAM limits
model = YOLO("yolo11s.pt")  

model.train(
    data=r"C:\Users\vuppa\Desktop\YOLO_Weapon_Detection\weapons\data.yaml",
    epochs=5,
    imgsz=640,
    batch=4,          # Lower batch size to prevent VRAM crashes
    name="weapon_detector",
    patience=20,
    device=0,         # RTX 3050
    workers=0,        # CRITICAL: Fixes the Windows multiprocessing CUDA spawn error
    plots=True        # saves training graphs
)
# Out:
# ...
# Ultralytics 8.4.60  Python-3.10.20 torch-2.11.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
import urllib.request
from ultralytics import YOLO

# Download the online image first
url = "data:image/jpeg;base64,..."
local_path = "temp_image.jpg"

headers = {'User-Agent': 'Mozilla/5.0'}
req = urllib.request.Request(url, headers=headers)
with urllib.request.urlopen(req) as response, open(local_path, 'wb') as out_file:
    out_file.write(response.read())

# Run YOLO prediction
model = YOLO(r"runs/detect/weapon_detector-5/weights/best.pt")
results = model.predict(source=local_path, save=True)
# Out:
# image 1/1 c:\Users\vuppa\Desktop\YOLO_Weapon_Detection\temp_image.jpg: 320x640 15 weapons, 139.8ms
# Speed: 2.6ms preprocess, 139.8ms inference, 16.8ms postprocess per image at shape (1, 3, 320, 640)
# Results saved to C:\Users\vuppa\desktop\YOLO_Weapon_Detection\runs\detect\predict-4
